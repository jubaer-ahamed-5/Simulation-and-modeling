# %%
import numpy as np
z1 = [ 12,7]
n=1000
for i in range(1,n):
  new_z = (13 * z1 [i - 1] + 11 * z1[i-2]+3) % 16
  z1.append(new_z)
  new_u=new_z/16
  u1.append(new_u)

# %%
z2 = [3,5]
u2 = []
n=1000
for i in range(1,n):
  new_z2 = (12 * z1[i-1**2]+13 * z1[i-2]) % 17
  z2.append(new_z2)
  new_u2=new_z2/17
  u2.append(new_u2)

# %%
z3 = [2,7]
u3 = []
n=1000
for i in range(1,n):
  new_z3 = (z3[i-1**3]+z3[i-2]**2)%15
  z3.append(new_z3)
  new_u3 = new_z3/15
  u3.append(new_u3)

# %%
u = []
for i in range(0,n-1):
  combined_u = u1[i]+u2[i]+u3[i]
  new_u=combined_u - int(combined_u)
  u.append(new_u)
print(u)
# Out:
# [0.5617647058823527, 0.9759803921568627, 0.24019607843137258, 0.7840686274509804, 0.04583333333333339, 0.9323529411764706, 0.2316176470588236, 0.3887254901960784, 0.3720588235294118, 0.09460784313725501, 0.42181372549019613, 0.6159313725490194, 0.280392156862745, 0.6620098039215687, 0.3176470588235294, 0.16029411764705892, 0.010784313725490158, 0.6242647058823527, 0.23210784313725497, 0.4019607843137254, 0.2718137254901962, 0.9465686274509806, 0.6406862745098039, 0.34558823529411775, 0.09338235294117658, 0.23357843137254908, 0.2735294117647058, 0.03946078431372557, 0.6931372549019608, 0.23872549019607847, 0.577450980392157, 0.566421568627451, 0.11250000000000004, 0.07941176470588207, 0.9159313725490196, 0.06911764705882373, 0.9093137254901961, 0.929901960784314, 0.004166666666666652, 0.4825980392156861, 0.6274509803921569, 0.9463235294117647, 0.5705882352941176, 0.7563725490196078, 0.5088235294117647, 0.10857843137254908, 0.6321078431372551, 0.4549019607843139, 0.7208333333333333, 0.
# ...

# %%
c_length = -1
for i in range(1,len(u)-1):
  if u[0]==u[i]:
    for j in range(1,i):
      if u[j]!=u[i + 1]:
        break
      c_lengt =i
      i=i+1

if c_length == -1:
  print("No cycle for " + str(n) + " random numbers")
else:
  print("Cycle  for " + str(n) + " random numbers")
  print("the cycle length is=" + str(cycle_length))
# Out:
# No cycle for 1000 random numbers

# %%
import matplotlib.pyplot as plot

# %%
plot.figure(figsize=(100, 5))
plot.bar(range(len(u)), u)
plot.show()
